# %%
import numpy
import pandas

# %%
haha = pandas.read_csv('iris.csv')

# %%
haha[['sepal_length','sepal_width','petal_length','petal_width','species']][:30] #[['a','b']]

# haha[:]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
from sklearn import tree

# %%
X = haha[['sepal_length','sepal_width','petal_length','petal_width']][:]
Y = haha[['species']][:]
# clf = tree.DecisionTreeClassifier()
# clf = clf.fit(X, Y)
# X,Y

# %%
# import pickle
# # now you can save it to a file
# with open('test.pkl', 'wb') as f:
#     pickle.dump(clf, f)

# %%
# clf.predict(haha[['sepal_length','sepal_width','petal_length','petal_width']][30:])

# %%
import numpy as np
from sklearn.model_selection import train_test_split
# X, Y = np.arange(10).reshape((5, 2)), range(5)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
X_train, X_test, y_train, y_test
# Out:
# (     sepal_length  sepal_width  petal_length  petal_width
#  22            4.6          3.6           1.0          0.2
#  15            5.7          4.4           1.5          0.4
#  65            6.7          3.1           4.4          1.4
#  11            4.8          3.4           1.6          0.2
#  42            4.4          3.2           1.3          0.2
#  146           6.3          2.5           5.0          1.9
#  51            6.4          3.2           4.5          1.5
#  27            5.2          3.5           1.5          0.2
#  4             5.0          3.6           1.4          0.2
#  32            5.2          4.1           1.5          0.1
#  142           5.8          2.7           5.1          1.9
#  85            6.0          3.4           4.5          1.6
#  86            6.7          3.1           4.7          1.5
#  16            5.4          3.9           1.3          0.4
#  10            5.4          3.7           1.5          0.2
# ...

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
# X,Y

# %%
# lol = pandas.DataFrame(clf.predict(X_test))
# lol = lol.append(y_train[0])
lol = clf.predict(X_test)
y_test['prediction'] = lol
y_test
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#         species  prediction
# 73   versicolor  versicolor
# 18       setosa      setosa
# 118   virginica   virginica
# 78   versicolor  versicolor
# 76   versicolor  versicolor
# 31       setosa      setosa
# 64   versicolor  versicolor
# 141   virginica   virginica
# 68   versicolor  versicolor
# 82   versicolor  versicolor
# 110   virginica   virginica
# 12       setosa      setosa
# 36       setosa      setosa
# 9        setosa      setosa
# 19       setosa      setosa
# 56   versicolor  versicolor
# 104   virginica   virginica
# 69   versicolor  versicolor
# 55   versicolor  versicolor
# ...

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test['spec'], pred)
# Out:
#               0     species
# 0    versicolor         NaN
# 1        setosa         NaN
# 2     virginica         NaN
# 3    versicolor         NaN
# 4    versicolor         NaN
# 5        setosa         NaN
# 6    versicolor         NaN
# 7     virginica         NaN
# 8    versicolor         NaN
# 9    versicolor         NaN
# 10    virginica         NaN
# 11       setosa         NaN
# 12       setosa         NaN
# 13       setosa         NaN
# 14       setosa         NaN
# 15   versicolor         NaN
# 16    virginica         NaN
# 17   versicolor         NaN
# 18   versicolor         NaN
# 19    virginica         NaN
# 20       setosa         NaN
# 21    virginica         NaN
# 22       setosa         NaN
# 23    virginica         NaN
# 24    virginica         NaN
# 25    virginica         NaN
# 26    virginica         NaN
# 27    virginica         NaN
# 28       setosa         NaN
# 29       setosa         NaN
# ..          ...         ...
# 91          NaN  versicolor
# ...
